# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
image= cv2.imread('images/lenna.png')
flipped_vertical=cv2.flip(image,1)
flipped_diagonal=cv2.flip(image,-1)
#added_image= cv2.add(flipped_diagonal,flipped_vertical)  ## Addition
sub_image= cv2.subtract(flipped_diagonal,flipped_vertical)  ## Subtracted
#cv2.imshow('Image', added_image)
cv2.imshow('Image', sub_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
img1=cv2.cvtColor(flipped_diagonal,cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(flipped_vertical,cv2.COLOR_BGR2RGB)
added=cv2.cvtColor(added_image,cv2.COLOR_BGR2RGB)
subtracted=cv2.cvtColor(sub_image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(16,9))
plt.subplot(1,3,1)
plt.title('Diagonal Image')
plt.imshow(img1)
plt.subplot(1,3,2)
plt.title('Vertical Image')
plt.imshow(img2)
plt.subplot(1,3,3)
#plt.title('Added Image')
#plt.imshow(added)
plt.title('Suntracted Image')
plt.imshow(subtracted)

# %%
alpha =0.25 # Transparency Factor
blended_image=cv2.addWeighted(img1,alpha,img2, 1-alpha,0)  # blending of image by a factor which ranges from 0-1
plt.figure(figsize=(16,9))
plt.subplot(1,3,1)
plt.title('Diagonal Image')
plt.imshow(img1)
plt.subplot(1,3,2)
plt.title('Vertical Image')
plt.imshow(img2)
plt.subplot(1,3,3)
plt.title('Blended Image')
plt.imshow(blended_image)

# %%
bright_image=cv2.multiply(img2, 1.5)  # Increase brightness by 1.5
plt.figure(figsize=(16,9))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(img2)
plt.subplot(1,3,2)
plt.title('Brighten Image')
plt.imshow(bright_image)
