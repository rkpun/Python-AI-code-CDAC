# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datasets/fb.csv')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df['Paid'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
co=df[df['Paid']==1]
co['Paid'].sum()
# Out:
# 139.0

# %%
df[['Type', 'Post Month','Page total likes','comment','share']]
# Out:
#        Type  Post Month  Page total likes  comment  share
# 0     Photo          12            139441        4   17.0
# 1    Status          12            139441        5   29.0
# 2     Photo          12            139441        0   14.0
# 3     Photo          12            139441       58  147.0
# 4     Photo          12            139441       19   49.0
# ..      ...         ...               ...      ...    ...
# 495   Photo           1             85093        5   26.0
# 496   Photo           1             81370        0   22.0
# 497   Photo           1             81370        4   18.0
# 498   Photo           1             81370        7   38.0
# 499   Photo           1             81370        0   28.0
#
# [500 rows x 5 columns]

# %%
sept=df[df['Post Month']==9]
sept['Page total likes'].mean()
# Out:
# 135185.33333333334

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df[df['Type']=='Link']
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22             138414  Link         1          12             7         10
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
# 47             138353  Link         1          12             3          2
# 49             138353  Link         1          12             2          2
# 86             137177  Link         1          11             4          3
# 136            136393  Link         1          10             5         10
# 140            136013  Link         1          10             4          3
# 149            135713  Link         1          10             6         11
# 344            117764  Link         1           5             1          2
# ...

# %%
vid=df[df['Type']=='Video']

# %%
vid['share'].sum()
# Out:
# 365.0

# %%
df['Post Hour'].unique()
# Out:
# array([ 3, 10,  9,  5, 12, 11,  2,  4,  8, 13,  7,  6,  1, 14, 23, 22, 15,
#        20, 19, 18, 17, 16], dtype=int64)

# %%
df.sort_values(['Post Hour'], ascending=False)      #Question 6, 7 Not Clear
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 230            131630  Photo         3           7             2         23
# 287            126141  Photo         1           6             4         22
# 381            109670  Photo         3           4             6         20
# 422            102112  Photo         1           3             1         19
# 424            102112  Photo         1           3             1         18
# ..                ...    ...       ...         ...           ...        ...
# 157            135700  Photo         3           9             2          2
# 212            132201  Photo         2           8             5          1
# 258            129600  Photo         2           7             3          1
# 333            119198  Photo         3           5             2          1
# 154            135713  Photo         2          10             4          1
#
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...
